# %%
#Q1.  write a python program to print "Hello python"

string = "Hello Python"
print(string)
# Out:
# Hello Python

# %%
#Q2.   write a python program to do Arithmetical operations Addition,divided,Multiple,subtract.

num1 = int(input())
num2 = int(input())
add = (num1+num2)
divided = (num1 / num2)
Multi = (num1*num2)
Sub = (num1-num2)
print("Addition:",add)
print("Division:",divided)
print("Multiple:",Multi)
print("sub:",Sub)
# Out:
#  24
#  12
# Addition: 36
# Division: 2.0
# Multiple: 288
# sub: 12

# %%
#Q3.   Write a Python program to find the area of a triangle?

Height = 3
Base = 7
Area = 1/2*Height*Base
print(Area)
# Out:
# 10.5

# %%
#Q4.   Write a Python program to swap two variables?

num1 = 12
num2 = 23
a,b = b,a
print("After swapping:")
print("num1=",num1)
print("num2=",num2)
# Out:
# After swapping:
# num1= 12
# num2= 23

# %%
#Q5.  Write a Python program to swap two variables?

import random

number = random.randint(1,999)
print("Random Number:", number)
# Out:
# Random Number: 948

# %%
#Q6.
